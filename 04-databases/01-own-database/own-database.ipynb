# %%
from IPython.display import Image

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.input').hide();
    } 
    else {
        $('div.input').show();
    }
    code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### Database schema:
# Figure out what the schema of the loaded database is!
#
# 1. Family Members
# 1.1 family
# 1.2 protein
# 1.2.1 species

# %% [markdown]
# ### Querying the database:
# Complete the following assignment by querying the loaded database using SQL.<br>
# 1. Add another species to the database: Sus scrofa!<br>
# 2. What proteins are longer than 1000 aa?<br>
# 3. What species are present in family NHR3? Give a full list with full species names using one SQL statement.<br>
# 4. How many proteins from each species are present in the database?<br>
#
#
#
# How do you change the schema to add information about a protein's structure? You want to store the name for the structure (such as 2xkg (Länkar till en externa sida.)Länkar till en externa sida., 5fvl (Länkar till en externa sida.)Länkar till en externa sida., or 6eny (Länkar till en externa sida.)Länkar till en externa sida.) , resolution (1.6Å, 1.97Å, or similar), and method ("Solution NMR", "X-ray diffraction"). Remember that a protein may have several structures published. Make your suggested changes and add some example data that you make up!

# %% [markdown]
# ### 1. What species are in the database?

# %%
Image("image1.png")

# %% [markdown]
# ### 2. Add another species to the database: Sus scrofa!

# %%
Image("image2.png")

# %% [markdown]
# ### 3. What proteins are longer than 1000 aa?

# %%
Image("image3.png")

# %% [markdown]
# ### 4. What species are present in family NHR3? Give a full list with full species names using one SQL statement.

# %%
Image("image5.png")

# %% [markdown]
# ### 5. How many proteins from each species are present in the database?

# %%
Image("image4.png")
